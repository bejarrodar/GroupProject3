# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
October = pd.read_csv('Sales_October_2019.csv')
November = pd.read_csv('Sales_November_2019.csv')
December = pd.read_csv('Sales_December_2019.csv')

# %%
q4 = pd.concat([October, November, December])
q4
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       259358      34in Ultrawide Monitor                1     379.99
# 1       259359      27in 4K Gaming Monitor                1     389.99
# 2       259360      AAA Batteries (4-pack)                2       2.99
# 3       259361            27in FHD Monitor                1     149.99
# 4       259362            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                           Purchase Address
# ...

# %%
filter = q4['Quantity Ordered'] != 'Quantity Ordered' 
q4= q4[filter]
q4
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       259358      34in Ultrawide Monitor                1     379.99
# 1       259359      27in 4K Gaming Monitor                1     389.99
# 2       259360      AAA Batteries (4-pack)                2       2.99
# 3       259361            27in FHD Monitor                1     149.99
# 4       259362            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                           Purchase Address
# ...

# %%
q4 = q4.dropna()
q4
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       259358      34in Ultrawide Monitor                1     379.99
# 1       259359      27in 4K Gaming Monitor                1     389.99
# 2       259360      AAA Batteries (4-pack)                2       2.99
# 3       259361            27in FHD Monitor                1     149.99
# 4       259362            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                           Purchase Address
# ...

# %%
q4.head()
# Out:
#   Order ID                 Product Quantity Ordered Price Each  \
# 0   259358  34in Ultrawide Monitor                1     379.99
# 1   259359  27in 4K Gaming Monitor                1     389.99
# 2   259360  AAA Batteries (4-pack)                2       2.99
# 3   259361        27in FHD Monitor                1     149.99
# 4   259362        Wired Headphones                1      11.99
#
#        Order Date                           Purchase Address
# 0  10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# 1  10/28/19 17:26          225 5th St, Los Angeles, CA 90001
# 2  10/24/19 17:20       967 12th St, New York City, NY 10001
# 3  10/14/19 22:26  628 Jefferson St, New York City, NY 10001
# 4  10/07/19 16:10         534 14th St, Los Angeles, CA 90001

# %%
sns.heatmap(data=pd.isnull(q4))

# %%
q4['city'] = q4['Purchase Address'].str.split(", ",expand=True)[1]
q4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       259358      34in Ultrawide Monitor                1     379.99
# 1       259359      27in 4K Gaming Monitor                1     389.99
# 2       259360      AAA Batteries (4-pack)                2       2.99
# 3       259361            27in FHD Monitor                1     149.99
# 4       259362            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# ...

# %%
q4['state'] = q4['Purchase Address'].str.split(", ",expand=True)[2].str.split(" ", expand=True)[0]
q4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       259358      34in Ultrawide Monitor                1     379.99
# 1       259359      27in 4K Gaming Monitor                1     389.99
# 2       259360      AAA Batteries (4-pack)                2       2.99
# 3       259361            27in FHD Monitor                1     149.99
# 4       259362            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# ...

# %%
q4['month'] = q4['Order Date'].str[0:2]
q4['year'] = q4['Order Date'].str[6:8]
q4['time'] = q4['Order Date'].str[-6:-3]
q4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
filter = q4['month'] != 1
q4 = q4[filter]

# %%
q4['Quantity Ordered'] = pd.to_numeric(q4['Quantity Ordered'])
q4['Price Each'] = pd.to_numeric(q4['Price Each'])
q4['month'] = pd.to_numeric(q4['month'])
q4['year'] = pd.to_numeric(q4['year'])
q4['time'] = pd.to_numeric(q4['time'])
q4['Order Date'] = pd.to_datetime(q4['Order Date'])

# %%
q4.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   259358  34in Ultrawide Monitor                 1      379.99
# 1   259359  27in 4K Gaming Monitor                 1      389.99
# 2   259360  AAA Batteries (4-pack)                 2        2.99
# 3   259361        27in FHD Monitor                 1      149.99
# 4   259362        Wired Headphones                 1       11.99
#
#            Order Date                           Purchase Address  \
# 0 2019-10-28 10:56:00            609 Cherry St, Dallas, TX 75001
# 1 2019-10-28 17:26:00          225 5th St, Los Angeles, CA 90001
# 2 2019-10-24 17:20:00       967 12th St, New York City, NY 10001
# 3 2019-10-14 22:26:00  628 Jefferson St, New York City, NY 10001
# 4 2019-10-07 16:10:00         534 14th St, Los Angeles, CA 90001
#
#             city state  month  year  time
# 0         Dallas    TX     10    19    10
# 1    Los Angeles    CA     10    19    17
# 2  New York City    NY     10    19    17
# ...

# %% [markdown]
# Number of products sold in each month

# %%
product_count = q4.groupby('month').count()
product_count
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# month
# 1            34       34                34          34          34
# 10        20262    20262             20262       20262       20262
# 11        17573    17573             17573       17573       17573
# 12        24984    24984             24984       24984       24984
#
#        Purchase Address   city  state   year   time
# month
# 1                    34     34     34     34     34
# 10                20262  20262  20262  20262  20262
# 11                17573  17573  17573  17573  17573
# 12                24984  24984  24984  24984  24984

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(
    data=product_count.reset_index(),
    x = 'month',
    y = 'Product'
)
plt.show()

# %% [markdown]
# Amount of money brought in by month

# %%
price_count = q4.groupby('month').sum()
price_count
# Out:
#        Quantity Ordered  Price Each    year    time
# month
# 1                    41     8503.40     680      52
# 10                22681  3712207.50  384978  290630
# 11                19798  3180600.68  333887  254865
# 12                28114  4588415.41  474696  359978

# %%
ax = sns.barplot(
    data = price_count.reset_index(),
    x = 'month',
    y = 'Price Each'
)
ax.set(xlabel='Month', ylabel='Income (Millions)')
plt.show()

# %% [markdown]
# Prices Of the different products

# %%
product_price = q4[['Product','Price Each']].drop_duplicates(subset=['Product','Price Each'])
product_price
# Out:
#                         Product  Price Each
# 0        34in Ultrawide Monitor      379.99
# 1        27in 4K Gaming Monitor      389.99
# 2        AAA Batteries (4-pack)        2.99
# 3              27in FHD Monitor      149.99
# 4              Wired Headphones       11.99
# 7      Lightning Charging Cable       14.95
# 8      Apple Airpods Headphones      150.00
# 11         USB-C Charging Cable       11.95
# 12                 20in Monitor      109.99
# 13                       iPhone      700.00
# 19   Bose SoundSport Headphones       99.99
# 23              ThinkPad Laptop      999.99
# 30        AA Batteries (4-pack)        3.84
# 33                 Google Phone      600.00
# 58              Vareebadd Phone      400.00
# 98                Flatscreen TV      300.00
# 115          Macbook Pro Laptop     1700.00
# 123                    LG Dryer      600.00
# 442          LG Washing Machine      600.00

# %%
sns.barplot(
    data=product_price,
    x = 'Product',
    y = 'Price Each'
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Number of each product sold

# %%
q4.groupby("Product").count()[['Order ID']]
# Out:
#                             Order ID
# Product
# 20in Monitor                    1415
# 27in 4K Gaming Monitor          2157
# 27in FHD Monitor                2462
# 34in Ultrawide Monitor          2065
# AA Batteries (4-pack)           6931
# AAA Batteries (4-pack)          7073
# Apple Airpods Headphones        5223
# Bose SoundSport Headphones      4485
# Flatscreen TV                   1644
# Google Phone                    1804
# LG Dryer                         192
# LG Washing Machine               194
# Lightning Charging Cable        7364
# Macbook Pro Laptop              1609
# ThinkPad Laptop                 1374
# USB-C Charging Cable            7486
# Vareebadd Phone                  665
# Wired Headphones                6424
# iPhone                          2286

# %%
sns.barplot(
    data= q4.groupby("Product").count()[['Order ID']].reset_index(),
    x = 'Product',
    y = 'Order ID'
)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Sales of each product by city

# %%
q4.groupby(['city','Product']).count()
# Out:
#                                 Order ID  Quantity Ordered  Price Each  \
# city    Product
# Atlanta 20in Monitor                 112               112         112
#         27in 4K Gaming Monitor       185               185         185
#         27in FHD Monitor             193               193         193
#         34in Ultrawide Monitor       166               166         166
#         AA Batteries (4-pack)        536               536         536
# ...                                  ...               ...         ...
# Seattle ThinkPad Laptop              114               114         114
#         USB-C Charging Cable         606               606         606
#         Vareebadd Phone               57                57          57
#         Wired Headphones             495               495         495
#         iPhone                       203               203         203
#
#                                 Order Date  Purchase Address  state  month  \
# city    Product
# ...

# %%
ax = sns.barplot(
    data=q4.groupby(['city','Product']).count().reset_index(),
    x = 'city',
    y = 'Order ID',
    hue = 'Product'
)
ax.set(xlabel='City', ylabel='Sales')
plt.show()

# %% [markdown]
# Sales of each product by state

# %%
q4.groupby(['state','Product']).count()
# Out:
#                               Order ID  Quantity Ordered  Price Each  \
# state Product
# CA    20in Monitor                 596               596         596
#       27in 4K Gaming Monitor       829               829         829
#       27in FHD Monitor             984               984         984
#       34in Ultrawide Monitor       792               792         792
#       AA Batteries (4-pack)       2745              2745        2745
# ...                                ...               ...         ...
# WA    ThinkPad Laptop              114               114         114
#       USB-C Charging Cable         606               606         606
#       Vareebadd Phone               57                57          57
#       Wired Headphones             495               495         495
#       iPhone                       203               203         203
#
#                               Order Date  Purchase Address  city  month  year  \
# state Product
# ...

# %%
sns.barplot(
    data=q4.groupby(['state','Product']).count().reset_index(),
    x = 'state',
    y = 'Order ID',
    hue = 'Product'
)

# %% [markdown]
# products sold by time

# %%
q4['time'].unique()
# Out:
# array([10, 17, 22, 16, 18, 11, 13, 23, 12, 20,  8,  0, 14, 15, 21, 19,  9,
#         4,  2,  7,  6,  1,  5,  3])

# %%
q4.groupby('time').count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# time
# 0         1304     1304              1304        1304        1304
# 1          811      811               811         811         811
# 2          399      399               399         399         399
# 3          285      285               285         285         285
# 4          317      317               317         317         317
# 5          437      437               437         437         437
# 6          866      866               866         866         866
# 7         1409     1409              1409        1409        1409
# 8         2020     2020              2020        2020        2020
# 9         2865     2865              2865        2865        2865
# 10        3734     3734              3734        3734        3734
# 11        4200     4200              4200        4200        4200
# 12        4309     4309              4309        4309        4309
# ...

# %%
ax = sns.countplot(x=q4['time'])
ax.set(xlabel='Time (Hour)', ylabel='Sales')
plt.show()
